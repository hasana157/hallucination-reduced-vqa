# %% [markdown]
# # Module 2: QLoRA Fine-Tuning Pipeline
# This notebook loads Qwen2-VL-2B-Instruct with 4-bit quantization, configures PEFT LoRA adapters, and trains on VQAv2 for 2 epochs (~3 GPU hours on T4).

# %%
# 1. Setup Environment
try:
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %env DATA_ROOT=/content/gdrive/My Drive/hallucination-reduced-vqa/data
except ImportError:
    print("Running locally")

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Execute QLoRA Fine-Tuning
# !python scripts/train.py --num_epochs 2 --learning_rate 1e-4 --batch_size 4
