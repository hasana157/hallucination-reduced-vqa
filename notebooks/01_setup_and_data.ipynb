# %% [markdown]
# # Module 1: Data Preparation & Infrastructure Setup
# This notebook sets up the environment on Google Colab, downloads VQAv2 and POPE datasets, and builds the FAISS vector index for RAG captions.

# %%
# 1. Mount Google Drive (if running in Google Colab)
try:
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %env DATA_ROOT=/content/gdrive/My Drive/hallucination-reduced-vqa/data
except ImportError:
    print("Running locally")

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Run Dataset Download & Validation
# !python scripts/download_datasets.py --validate

# %%
# 4. Build CLIP Embeddings & FAISS Index
# !python scripts/build_faiss_index.py
